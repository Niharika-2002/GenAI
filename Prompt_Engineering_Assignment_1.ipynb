# %%
# !pip install -q groq
# !pip install -q litellm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 44.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.8 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

# %%
groq_api_key = "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"
hf_api_key = "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"
os.environ["GROQ_API_KEY"] = groq_api_key
os.environ["HF_API_KEY"] = hf_api_key

# %%
from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of large language models",
        }
    ],
    model="llama3-8b-8192",
)

print(chat_completion.choices[0].message.content)
# Out:
# Large language models (LLMs) have become a crucial aspect of modern natural language processing (NLP) and artificial intelligence (AI). Their importance lies in their ability to perform a wide range of tasks, from understanding human language to generating high-quality text. Here are some reasons why LLMs are important:
#
# 1. **Improved language understanding**: LLMs can accurately understand human language, including nuances, idioms, and context-dependent meaning. This capability enables them to process and analyze large amounts of text data, making them valuable for applications like sentiment analysis, information retrieval, and question answering.
# 2. **Natural Language Generation**: LLMs can generate high-quality text, including articles, stories, and responses to queries. This capability is useful for applications like text summarization, chatbots, and automatic content generation.
# ...

# %%
from litellm import completion

# %%
ftext = """
Black holes — those mysterious cosmic phenomena — are regions in space with gravitational forces so intense that not even light can escape.
Astrophysicists Dr. Alan Rothwell and Prof. Priya Sinha have deeply explored the science of these objects, uncovering fascinating insights.

According to Rothwell’s research (2021), black holes form when massive stars burn through their fuel and collapse under gravity until they reach a singularity — a point of nearly infinite density where physics breaks down.

Sinha’s studies focus on the event horizon, or the "point of no return"; any matter or light crossing this boundary is trapped forever. She also examines Hawking Radiation — a theoretical concept proposed by Stephen Hawking — suggesting that black holes emit small amounts of energy, slowly losing mass. Such radiation might allow scientists to peek inside these intense entities.

Together, Rothwell and Sinha’s studies hint at bridging quantum mechanics with general relativity — fields otherwise tough to reconcile.
"""

# %%
prompt = f"""Summarize the following article {ftext} for as following:
1. Highschool student
2. Layman
3. An expert """

# %%
def get_response(prompt):
    model = "groq/llama3-70b-8192"
    messages = [{"role": "user", "content": prompt}]

    response = completion(
        model=model,
        messages=messages
    )

    return response['choices'][0]['message']['content'] or ""

# %%
res = get_response(prompt)
print(res)
# Out:
# Here are three summaries of the article, tailored for different audiences:
#
# **For a High School Student:**
#
# Black holes are really cool and really weird things in space. They're so dense and have such strong gravity that not even light can escape once it gets too close. Two scientists, Dr. Alan Rothwell and Prof. Priya Sinha, have been studying black holes to learn more about them. Dr. Rothwell found out that black holes are formed when a massive star runs out of fuel and collapses in on itself. Prof. Sinha looked at the "point of no return" around a black hole, where anything that crosses the line gets stuck forever. She also explored an idea called Hawking Radiation, which suggests that black holes might slowly release some energy over time. Their research helps us understand these mysterious objects better!
#
# **For a Layman:**
#
# ...
